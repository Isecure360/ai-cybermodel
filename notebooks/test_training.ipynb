# %%
from phishi

X_train, X_test, y_train, y_test, meta = load_prepare_split("PhiUSIIL_Phishing_URL_Dataset.csv")

print(meta.class_distribution)
print("Numeric:", meta.numeric_features[:10])
print("Categorical:", meta.categorical_features)
print("Text:", meta.text_features)
print("URL:", meta.url_features)
